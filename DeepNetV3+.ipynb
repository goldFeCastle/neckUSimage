# %% [markdown]
# <a href="https://colab.research.google.com/github/goldFeCastle/neckUSimage/blob/master/DeepNetV3%2B.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import numpy as np

from keras.models import Model
from keras import layers
from keras.layers import Input,Activation,Concatenate,Add,Dropout,BatchNormalization,\
Conv2D,DepthwiseConv2D,ZeroPadding2D,AveragePooling2D
from keras.engine import Layer,InputSpec
from keras.engine.topology import get_source_inputs
from keras.applications import imagenet_utils
from keras.utils import conv_utils
from keras.utils.data_utils import get_file

from keras import backend as K

# %%
WEIGHTS_PATH_X = "https://github.com/bonlime/keras-deeplab-v3-plus/releases/download/1.1/deeplabv3_xception_tf_dim_ordering_tf_kernels.h5"
WEIGHTS_PATH_MOBILE = "https://github.com/bonlime/keras-deeplab-v3-plus/releases/download/1.1/deeplabv3_mobilenetv2_tf_dim_ordering_tf_kernels.h5"

# %% [markdown]
# # BilinearUpsampling

# %%
class BilinearUpsampling(Layer):
    """Just a simple bilinear upsampling layer. Works only with TF.
       Args:
           upsampling: tuple of 2 numbers > 0. The upsampling ratio for h and w
           output_size: used instead of upsampling arg if passed!
    """

    def __init__(self, upsampling=(2, 2), output_size=None, data_format=None, **kwargs):

        super(BilinearUpsampling, self).__init__(**kwargs)

        self.data_format = K.normalize_data_format(data_format)
        self.input_spec = InputSpec(ndim=4)
        if output_size:
            self.output_size = conv_utils.normalize_tuple(
                output_size, 2, 'output_size')
            self.upsampling = None
        else:
            self.output_size = None
            self.upsampling = conv_utils.normalize_tuple(
                upsampling, 2, 'upsampling')

    def compute_output_shape(self, input_shape):
        if self.upsampling:
            height = self.upsampling[0] * \
                input_shape[1] if input_shape[1] is not None else None
            width = self.upsampling[1] * \
                input_shape[2] if input_shape[2] is not None else None
        else:
            height = self.output_size[0]
            width = self.output_size[1]
        return (input_shape[0],
                height,
                width,
                input_shape[3])

    def call(self, inputs):
        if self.upsampling:
            return K.tf.image.resize_bilinear(inputs, (inputs.shape[1] * self.upsampling[0],
                                                       inputs.shape[2] * self.upsampling[1]),
                                              align_corners=True)
        else:
            return K.tf.image.resize_bilinear(inputs, (self.output_size[0],
                                                       self.output_size[1]),
                                              align_corners=True)

    def get_config(self):
        config = {'upsampling': self.upsampling,
                  'output_size': self.output_size,
                  'data_format': self.data_format}
        base_config = super(BilinearUpsampling, self).get_config()
        return dict(list(base_config.items()) + list(config.items()))

# %% [markdown]
# # Conv layer

# %%
def SepConv_BN(x, filters, prefix, stride=1, kernel_size=3, rate=1, depth_activation=False, epsilon=1e-3):

    if stride == 1:
        depth_padding = 'same'
    else:
        kernel_size_effective = kernel_size + (kernel_size - 1) * (rate - 1)
        pad_total = kernel_size_effective - 1
        pad_beg = pad_total // 2
        pad_end = pad_total - pad_beg
        x = ZeroPadding2D((pad_beg, pad_end))(x)
        depth_padding = 'valid'

    if not depth_activation:
        x = Activation('relu')(x)
    x = DepthwiseConv2D((kernel_size, kernel_size), strides=(stride, stride), dilation_rate=(rate, rate),
                        padding=depth_padding, use_bias=False, name=prefix + '_depthwise')(x)
    x = BatchNormalization(name=prefix + '_depthwise_BN', epsilon=epsilon)(x)
    if depth_activation:
        x = Activation('relu')(x)
    x = Conv2D(filters, (1, 1), padding='same',
               use_bias=False, name=prefix + '_pointwise')(x)
    x = BatchNormalization(name=prefix + '_pointwise_BN', epsilon=epsilon)(x)
    if depth_activation:
        x = Activation('relu')(x)

    return x


def _conv2d_same(x, filters, prefix, stride=1, kernel_size=3, rate=1):
    if stride == 1:
        return Conv2D(filters,
                      (kernel_size, kernel_size),
                      strides=(stride, stride),
                      padding='same', use_bias=False,
                      dilation_rate=(rate, rate),
                      name=prefix)(x)
    else:
        kernel_size_effective = kernel_size + (kernel_size - 1) * (rate - 1)
        pad_total = kernel_size_effective - 1
        pad_beg = pad_total // 2
        pad_end = pad_total - pad_beg
        x = ZeroPadding2D((pad_beg, pad_end))(x)
        return Conv2D(filters,
                      (kernel_size, kernel_size),
                      strides=(stride, stride),
                      padding='valid', use_bias=False,
                      dilation_rate=(rate, rate),
                      name=prefix)(x)

# %% [markdown]
# # xception_block

# %%
def _xception_block(inputs, depth_list, prefix, skip_connection_type, stride,
                    rate=1, depth_activation=False, return_skip=False):
    """ Basic building block of modified Xception network
        Args:
            inputs: input tensor
            depth_list: number of filters in each SepConv layer. len(depth_list) == 3
            prefix: prefix before name
            skip_connection_type: one of {'conv','sum','none'}
            stride: stride at last depthwise conv
            rate: atrous rate for depthwise convolution
            depth_activation: flag to use activation between depthwise & pointwise convs
            return_skip: flag to return additional tensor after 2 SepConvs for decoder
            """
    residual = inputs
    for i in range(3):
        residual = SepConv_BN(residual,
                              depth_list[i],
                              prefix + '_separable_conv{}'.format(i + 1),
                              stride=stride if i == 2 else 1,
                              rate=rate,
                              depth_activation=depth_activation)
        if i == 1:
            skip = residual
    if skip_connection_type == 'conv':
        shortcut = _conv2d_same(inputs, depth_list[-1], prefix + '_shortcut',
                                kernel_size=1,
                                stride=stride)
        shortcut = BatchNormalization(name=prefix + '_shortcut_BN')(shortcut)
        outputs = layers.add([residual, shortcut])
    elif skip_connection_type == 'sum':
        outputs = layers.add([residual, inputs])
    elif skip_connection_type == 'none':
        outputs = residual
    if return_skip:
        return outputs, skip
    else:
        return outputs

# %% [markdown]
# # Activision layer

# %%
def relu6(x):
    return K.relu(x, max_value=6)


def _make_divisible(v, divisor, min_value=None):
    if min_value is None:
        min_value = divisor
    new_v = max(min_value, int(v + divisor / 2) // divisor * divisor)
    # Make sure that round down does not go down by more than 10%.
    if new_v < 0.9 * v:
        new_v += divisor
    return new_v

# %% [markdown]
# # res block

# %%
def _inverted_res_block(inputs, expansion, stride, alpha, filters, block_id, skip_connection, rate=1):
    in_channels = inputs._keras_shape[-1]
    pointwise_conv_filters = int(filters * alpha)
    pointwise_filters = _make_divisible(pointwise_conv_filters, 8)
    x = inputs
    prefix = 'expanded_conv_{}_'.format(block_id)
    if block_id:
        # Expand

        x = Conv2D(expansion * in_channels, kernel_size=1, padding='same',
                   use_bias=False, activation=None,
                   name=prefix + 'expand')(x)
        x = BatchNormalization(epsilon=1e-3, momentum=0.999,
                               name=prefix + 'expand_BN')(x)
        x = Activation(relu6, name=prefix + 'expand_relu')(x)
        x = layers.Dropout(0.5)(x)
    else:
        prefix = 'expanded_conv_'
    # Depthwise
    x = DepthwiseConv2D(kernel_size=3, strides=stride, activation=None,
                        use_bias=False, padding='same', dilation_rate=(rate, rate),
                        name=prefix + 'depthwise')(x)
    x = BatchNormalization(epsilon=1e-3, momentum=0.999,
                           name=prefix + 'depthwise_BN')(x)

    x = Activation(relu6, name=prefix + 'depthwise_relu')(x)

    # Project
    x = Conv2D(pointwise_filters,
               kernel_size=1, padding='same', use_bias=False, activation=None,
               name=prefix + 'project')(x)
    x = BatchNormalization(epsilon=1e-3, momentum=0.999,
                           name=prefix + 'project_BN')(x)

    if skip_connection:
        return Add(name=prefix + 'add')([inputs, x])

    # if in_channels == pointwise_filters and stride == 1:
    #    return Add(name='res_connect_' + str(block_id))([inputs, x])

    return x

# %% [markdown]
# # Deeplab

# %%
def Deeplabv3(weights='pascal_voc', input_tensor=None, input_shape=(512, 512, 3), classes=1, backbone='mobilenetv2', OS=16, alpha=1.):
    if not (weights in {'pascal_voc', None}):
        raise ValueError('The `weights` argument should be either '
                         '`None` (random initialization) or `pascal_voc` '
                         '(pre-trained on PASCAL VOC)')

    if K.backend() != 'tensorflow':
        raise RuntimeError('The Deeplabv3+ model is only available with '
                           'the TensorFlow backend.')

    if not (backbone in {'xception', 'mobilenetv2'}):
        raise ValueError('The `backbone` argument should be either '
                         '`xception`  or `mobilenetv2` ')

    if input_tensor is None:
        img_input = Input(shape=input_shape)
    else:
        if not K.is_keras_tensor(input_tensor):
            img_input = Input(tensor=input_tensor, shape=input_shape)
        else:
            img_input = input_tensor

    if backbone == 'xception':
        if OS == 8:
            entry_block3_stride = 1
            middle_block_rate = 2  # ! Not mentioned in paper, but required
            exit_block_rates = (2, 4)
            atrous_rates = (12, 24, 36)
        else:
            entry_block3_stride = 2
            middle_block_rate = 1
            exit_block_rates = (1, 2)
            atrous_rates = (6, 12, 18)

        x = Conv2D(32, (3, 3), strides=(2, 2),
                   name='entry_flow_conv1_1', use_bias=False, padding='same')(img_input)
        x = BatchNormalization(name='entry_flow_conv1_1_BN')(x)
        x = Activation('relu')(x)

        x = _conv2d_same(x, 64, 'entry_flow_conv1_2', kernel_size=3, stride=1)
        x = BatchNormalization(name='entry_flow_conv1_2_BN')(x)
        x = Activation('relu')(x)

        x = _xception_block(x, [128, 128, 128], 'entry_flow_block1',
                            skip_connection_type='conv', stride=2,
                            depth_activation=False)
        x, skip1 = _xception_block(x, [256, 256, 256], 'entry_flow_block2',
                                   skip_connection_type='conv', stride=2,
                                   depth_activation=False, return_skip=True)

        x = _xception_block(x, [728, 728, 728], 'entry_flow_block3',
                            skip_connection_type='conv', stride=entry_block3_stride,
                            depth_activation=False)
        for i in range(16):
            x = _xception_block(x, [728, 728, 728], 'middle_flow_unit_{}'.format(i + 1),
                                skip_connection_type='sum', stride=1, rate=middle_block_rate,
                                depth_activation=False)

        x = _xception_block(x, [728, 1024, 1024], 'exit_flow_block1',
                            skip_connection_type='conv', stride=1, rate=exit_block_rates[0],
                            depth_activation=False)
        x = _xception_block(x, [1536, 1536, 2048], 'exit_flow_block2',
                            skip_connection_type='none', stride=1, rate=exit_block_rates[1],
                            depth_activation=True)

    else:
        OS = 8
        first_block_filters = _make_divisible(32 * alpha, 8)
        x = Conv2D(first_block_filters,
                   kernel_size=3,
                   strides=(2, 2), padding='same',
                   use_bias=False, name='Conv')(img_input)
        x = BatchNormalization(
            epsilon=1e-3, momentum=0.999, name='Conv_BN')(x)
        x = Activation(relu6, name='Conv_Relu6')(x)

        x = _inverted_res_block(x, filters=16, alpha=alpha, stride=1,
                                expansion=1, block_id=0, skip_connection=False)

        x = _inverted_res_block(x, filters=24, alpha=alpha, stride=2,
                                expansion=6, block_id=1, skip_connection=False)
        x = _inverted_res_block(x, filters=24, alpha=alpha, stride=1,
                                expansion=6, block_id=2, skip_connection=True)

        x = _inverted_res_block(x, filters=32, alpha=alpha, stride=2,
                                expansion=6, block_id=3, skip_connection=False)
        x = _inverted_res_block(x, filters=32, alpha=alpha, stride=1,
                                expansion=6, block_id=4, skip_connection=True)
        x = _inverted_res_block(x, filters=32, alpha=alpha, stride=1,
                                expansion=6, block_id=5, skip_connection=True)

        # stride in block 6 changed from 2 -> 1, so we need to use rate = 2
        x = _inverted_res_block(x, filters=64, alpha=alpha, stride=1,  # 1!
                                expansion=6, block_id=6, skip_connection=False)
        x = _inverted_res_block(x, filters=64, alpha=alpha, stride=1, rate=2,
                                expansion=6, block_id=7, skip_connection=True)
        x = _inverted_res_block(x, filters=64, alpha=alpha, stride=1, rate=2,
                                expansion=6, block_id=8, skip_connection=True)
        x = _inverted_res_block(x, filters=64, alpha=alpha, stride=1, rate=2,
                                expansion=6, block_id=9, skip_connection=True)

        x = _inverted_res_block(x, filters=96, alpha=alpha, stride=1, rate=2,
                                expansion=6, block_id=10, skip_connection=False)
        x = _inverted_res_block(x, filters=96, alpha=alpha, stride=1, rate=2,
                                expansion=6, block_id=11, skip_connection=True)
        x = _inverted_res_block(x, filters=96, alpha=alpha, stride=1, rate=2,
                                expansion=6, block_id=12, skip_connection=True)

        x = _inverted_res_block(x, filters=160, alpha=alpha, stride=1, rate=2,  # 1!
                                expansion=6, block_id=13, skip_connection=False)
        x = _inverted_res_block(x, filters=160, alpha=alpha, stride=1, rate=4,
                                expansion=6, block_id=14, skip_connection=True)
        x = _inverted_res_block(x, filters=160, alpha=alpha, stride=1, rate=4,
                                expansion=6, block_id=15, skip_connection=True)

        x = _inverted_res_block(x, filters=320, alpha=alpha, stride=1, rate=4,
                                expansion=6, block_id=16, skip_connection=False)

    # end of feature extractor

    # branching for Atrous Spatial Pyramid Pooling

    # Image Feature branch
    #out_shape = int(np.ceil(input_shape[0] / OS))
    b4 = AveragePooling2D(pool_size=(int(np.ceil(input_shape[0] / OS)), int(np.ceil(input_shape[1] / OS))))(x)
    b4 = Conv2D(256, (1, 1), padding='same',
                use_bias=False, name='image_pooling')(b4)
    b4 = BatchNormalization(name='image_pooling_BN', epsilon=1e-5)(b4)
    b4 = Activation('relu')(b4)
    b4 = BilinearUpsampling((int(np.ceil(input_shape[0] / OS)), int(np.ceil(input_shape[1] / OS))))(b4)

    # simple 1x1
    b0 = Conv2D(256, (1, 1), padding='same', use_bias=False, name='aspp0')(x)
    b0 = BatchNormalization(name='aspp0_BN', epsilon=1e-5)(b0)
    b0 = Activation('relu', name='aspp0_activation')(b0)

    # there are only 2 branches in mobilenetV2. not sure why
    if backbone == 'xception':
        # rate = 6 (12)
        b1 = SepConv_BN(x, 256, 'aspp1',
                        rate=atrous_rates[0], depth_activation=True, epsilon=1e-5)
        # rate = 12 (24)
        b2 = SepConv_BN(x, 256, 'aspp2',
                        rate=atrous_rates[1], depth_activation=True, epsilon=1e-5)
        # rate = 18 (36)
        b3 = SepConv_BN(x, 256, 'aspp3',
                        rate=atrous_rates[2], depth_activation=True, epsilon=1e-5)

        # concatenate ASPP branches & project
        x = Concatenate()([b4, b0, b1, b2, b3])
    else:
        x = Concatenate()([b4, b0])

    x = Conv2D(256, (1, 1), padding='same',
               use_bias=False, name='concat_projection')(x)
    x = BatchNormalization(name='concat_projection_BN', epsilon=1e-5)(x)
    x = Activation('relu')(x)
    x = Dropout(0.1)(x)

    # DeepLab v.3+ decoder

    if backbone == 'xception':
        # Feature projection
        # x4 (x2) block
        x = BilinearUpsampling(output_size=(int(np.ceil(input_shape[0] / 4)),
                                            int(np.ceil(input_shape[1] / 4))))(x)
        dec_skip1 = Conv2D(48, (1, 1), padding='same',
                           use_bias=False, name='feature_projection0')(skip1)
        dec_skip1 = BatchNormalization(
            name='feature_projection0_BN', epsilon=1e-5)(dec_skip1)
        dec_skip1 = Activation('relu')(dec_skip1)
        x = Concatenate()([x, dec_skip1])
        x = SepConv_BN(x, 256, 'decoder_conv0',
                       depth_activation=True, epsilon=1e-5)
        x = SepConv_BN(x, 256, 'decoder_conv1',
                       depth_activation=True, epsilon=1e-5)

    # you can use it with arbitary number of classes
    if classes == 21:
        last_layer_name = 'logits_semantic'
    else:
        last_layer_name = 'custom_logits_semantic'

    x = Conv2D(classes, (1, 1), padding='same', name=last_layer_name)(x)
    x = BilinearUpsampling(output_size=(input_shape[0], input_shape[1]))(x)

    # Ensure that the model takes into account
    # any potential predecessors of `input_tensor`.
    if input_tensor is not None:
        inputs = get_source_inputs(input_tensor)
    else:
        inputs = img_input

    model = Model(inputs, x, name='deeplabv3plus')
    return model

    # load weights
'''
    if weights == 'pascal_voc':
        if backbone == 'xception':
            weights_path = get_file('deeplabv3_xception_tf_dim_ordering_tf_kernels.h5',
                                    WEIGHTS_PATH_X,
                                    cache_subdir='models')
        else:
            weights_path = get_file('deeplabv3_mobilenetv2_tf_dim_ordering_tf_kernels.h5',
                                    WEIGHTS_PATH_MOBILE,
                                    cache_subdir='models')
        model.load_weights(weights_path, by_name=True)
'''
# Out:
# "\n    if weights == 'pascal_voc':\n        if backbone == 'xception':\n            weights_path = get_file('deeplabv3_xception_tf_dim_ordering_tf_kernels.h5',\n                                    WEIGHTS_PATH_X,\n                                    cache_subdir='models')\n        else:\n            weights_path = get_file('deeplabv3_mobilenetv2_tf_dim_ordering_tf_kernels.h5',\n                                    WEIGHTS_PATH_MOBILE,\n                                    cache_subdir='models')\n        model.load_weights(weights_path, by_name=True)\n"

# %%
model = Deeplabv3(input_shape=(96, 96, 1))

# %%
print((model.summary()))
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            (None, 96, 96, 1)    0
# __________________________________________________________________________________________________
# Conv (Conv2D)                   (None, 48, 48, 32)   288         input_2[0][0]
# __________________________________________________________________________________________________
# Conv_BN (BatchNormalization)    (None, 48, 48, 32)   128         Conv[0][0]
# __________________________________________________________________________________________________
# Conv_Relu6 (Activation)         (None, 48, 48, 32)   0           Conv_BN[0][0]
# __________________________________________________________________________________________________
# expanded_conv_depthwise (Depthw (None, 48, 48, 32)   288         Conv_Relu6[0][0]
# __________________________________________________________________________________________________
# expanded_conv_depthwise_BN (Bat (None, 48, 48, 32)   128         expanded_conv_depthwise[0][0]
# __________________________________________________________________________________________________
# expanded_conv_depthwise_relu (A (None, 48, 48, 32)   0           expanded_conv_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# expanded_conv_project (Conv2D)  (None, 48, 48, 16)   512         expanded_conv_depthwise_relu[0][0
# __________________________________________________________________________________________________
# expanded_conv_project_BN (Batch (None, 48, 48, 16)   64          expanded_conv_project[0][0]
# __________________________________________________________________________________________________
# expanded_conv_1_expand (Conv2D) (None, 48, 48, 96)   1536        expanded_conv_project_BN[0][0]
# __________________________________________________________________________________________________
# expanded_conv_1_expand_BN (Batc (None, 48, 48, 96)   384         expanded_conv_1_expand[0][0]
# __________________________________________________________________________________________________
# expanded_conv_1_expand_relu (Ac (None, 48, 48, 96)   0           expanded_conv_1_expand_BN[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 48, 48, 96)   0           expanded_conv_1_expand_relu[0][0]
# __________________________________________________________________________________________________
# expanded_conv_1_depthwise (Dept (None, 24, 24, 96)   864         dropout_2[0][0]
# __________________________________________________________________________________________________
# expanded_conv_1_depthwise_BN (B (None, 24, 24, 96)   384         expanded_conv_1_depthwise[0][0]
# __________________________________________________________________________________________________
# expanded_conv_1_depthwise_relu  (None, 24, 24, 96)   0           expanded_conv_1_depthwise_BN[0][0
# __________________________________________________________________________________________________
# expanded_conv_1_project (Conv2D (None, 24, 24, 24)   2304        expanded_conv_1_depthwise_relu[0]
# __________________________________________________________________________________________________
# expanded_conv_1_project_BN (Bat (None, 24, 24, 24)   96          expanded_conv_1_project[0][0]
# __________________________________________________________________________________________________
# expanded_conv_2_expand (Conv2D) (None, 24, 24, 144)  3456        expanded_conv_1_project_BN[0][0]
# __________________________________________________________________________________________________
# expanded_conv_2_expand_BN (Batc (None, 24, 24, 144)  576         expanded_conv_2_expand[0][0]
# __________________________________________________________________________________________________
# expanded_conv_2_expand_relu (Ac (None, 24, 24, 144)  0           expanded_conv_2_expand_BN[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 24, 24, 144)  0           expanded_conv_2_expand_relu[0][0]
# __________________________________________________________________________________________________
# expanded_conv_2_depthwise (Dept (None, 24, 24, 144)  1296        dropout_3[0][0]
# __________________________________________________________________________________________________
# expanded_conv_2_depthwise_BN (B (None, 24, 24, 144)  576         expanded_conv_2_depthwise[0][0]
# __________________________________________________________________________________________________
# expanded_conv_2_depthwise_relu  (None, 24, 24, 144)  0           expanded_conv_2_depthwise_BN[0][0
# __________________________________________________________________________________________________
# expanded_conv_2_project (Conv2D (None, 24, 24, 24)   3456        expanded_conv_2_depthwise_relu[0]
# __________________________________________________________________________________________________
# expanded_conv_2_project_BN (Bat (None, 24, 24, 24)   96          expanded_conv_2_project[0][0]
# __________________________________________________________________________________________________
# expanded_conv_2_add (Add)       (None, 24, 24, 24)   0           expanded_conv_1_project_BN[0][0]
#                                                                  expanded_conv_2_project_BN[0][0]
# __________________________________________________________________________________________________
# expanded_conv_3_expand (Conv2D) (None, 24, 24, 144)  3456        expanded_conv_2_add[0][0]
# __________________________________________________________________________________________________
# expanded_conv_3_expand_BN (Batc (None, 24, 24, 144)  576         expanded_conv_3_expand[0][0]
# __________________________________________________________________________________________________
# expanded_conv_3_expand_relu (Ac (None, 24, 24, 144)  0           expanded_conv_3_expand_BN[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 24, 24, 144)  0           expanded_conv_3_expand_relu[0][0]
# __________________________________________________________________________________________________
# expanded_conv_3_depthwise (Dept (None, 12, 12, 144)  1296        dropout_4[0][0]
# __________________________________________________________________________________________________
# expanded_conv_3_depthwise_BN (B (None, 12, 12, 144)  576         expanded_conv_3_depthwise[0][0]
# __________________________________________________________________________________________________
# expanded_conv_3_depthwise_relu  (None, 12, 12, 144)  0           expanded_conv_3_depthwise_BN[0][0
# __________________________________________________________________________________________________
# expanded_conv_3_project (Conv2D (None, 12, 12, 32)   4608        expanded_conv_3_depthwise_relu[0]
# __________________________________________________________________________________________________
# expanded_conv_3_project_BN (Bat (None, 12, 12, 32)   128         expanded_conv_3_project[0][0]
# __________________________________________________________________________________________________
# expanded_conv_4_expand (Conv2D) (None, 12, 12, 192)  6144        expanded_conv_3_project_BN[0][0]
# __________________________________________________________________________________________________
# expanded_conv_4_expand_BN (Batc (None, 12, 12, 192)  768         expanded_conv_4_expand[0][0]
# __________________________________________________________________________________________________
# expanded_conv_4_expand_relu (Ac (None, 12, 12, 192)  0           expanded_conv_4_expand_BN[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 12, 12, 192)  0           expanded_conv_4_expand_relu[0][0]
# __________________________________________________________________________________________________
# expanded_conv_4_depthwise (Dept (None, 12, 12, 192)  1728        dropout_5[0][0]
# __________________________________________________________________________________________________
# expanded_conv_4_depthwise_BN (B (None, 12, 12, 192)  768         expanded_conv_4_depthwise[0][0]
# __________________________________________________________________________________________________
# expanded_conv_4_depthwise_relu  (None, 12, 12, 192)  0           expanded_conv_4_depthwise_BN[0][0
# __________________________________________________________________________________________________
# expanded_conv_4_project (Conv2D (None, 12, 12, 32)   6144        expanded_conv_4_depthwise_relu[0]
# __________________________________________________________________________________________________
# expanded_conv_4_project_BN (Bat (None, 12, 12, 32)   128         expanded_conv_4_project[0][0]
# __________________________________________________________________________________________________
# expanded_conv_4_add (Add)       (None, 12, 12, 32)   0           expanded_conv_3_project_BN[0][0]
#                                                                  expanded_conv_4_project_BN[0][0]
# __________________________________________________________________________________________________
# expanded_conv_5_expand (Conv2D) (None, 12, 12, 192)  6144        expanded_conv_4_add[0][0]
# __________________________________________________________________________________________________
# expanded_conv_5_expand_BN (Batc (None, 12, 12, 192)  768         expanded_conv_5_expand[0][0]
# __________________________________________________________________________________________________
# expanded_conv_5_expand_relu (Ac (None, 12, 12, 192)  0           expanded_conv_5_expand_BN[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 12, 12, 192)  0           expanded_conv_5_expand_relu[0][0]
# __________________________________________________________________________________________________
# expanded_conv_5_depthwise (Dept (None, 12, 12, 192)  1728        dropout_6[0][0]
# __________________________________________________________________________________________________
# expanded_conv_5_depthwise_BN (B (None, 12, 12, 192)  768         expanded_conv_5_depthwise[0][0]
# __________________________________________________________________________________________________
# expanded_conv_5_depthwise_relu  (None, 12, 12, 192)  0           expanded_conv_5_depthwise_BN[0][0
# __________________________________________________________________________________________________
# expanded_conv_5_project (Conv2D (None, 12, 12, 32)   6144        expanded_conv_5_depthwise_relu[0]
# __________________________________________________________________________________________________
# expanded_conv_5_project_BN (Bat (None, 12, 12, 32)   128         expanded_conv_5_project[0][0]
# __________________________________________________________________________________________________
# expanded_conv_5_add (Add)       (None, 12, 12, 32)   0           expanded_conv_4_add[0][0]
#                                                                  expanded_conv_5_project_BN[0][0]
# __________________________________________________________________________________________________
# expanded_conv_6_expand (Conv2D) (None, 12, 12, 192)  6144        expanded_conv_5_add[0][0]
# __________________________________________________________________________________________________
# expanded_conv_6_expand_BN (Batc (None, 12, 12, 192)  768         expanded_conv_6_expand[0][0]
# __________________________________________________________________________________________________
# expanded_conv_6_expand_relu (Ac (None, 12, 12, 192)  0           expanded_conv_6_expand_BN[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 12, 12, 192)  0           expanded_conv_6_expand_relu[0][0]
# __________________________________________________________________________________________________
# expanded_conv_6_depthwise (Dept (None, 12, 12, 192)  1728        dropout_7[0][0]
# __________________________________________________________________________________________________
# expanded_conv_6_depthwise_BN (B (None, 12, 12, 192)  768         expanded_conv_6_depthwise[0][0]
# __________________________________________________________________________________________________
# expanded_conv_6_depthwise_relu  (None, 12, 12, 192)  0           expanded_conv_6_depthwise_BN[0][0
# __________________________________________________________________________________________________
# expanded_conv_6_project (Conv2D (None, 12, 12, 64)   12288       expanded_conv_6_depthwise_relu[0]
# __________________________________________________________________________________________________
# expanded_conv_6_project_BN (Bat (None, 12, 12, 64)   256         expanded_conv_6_project[0][0]
# __________________________________________________________________________________________________
# expanded_conv_7_expand (Conv2D) (None, 12, 12, 384)  24576       expanded_conv_6_project_BN[0][0]
# __________________________________________________________________________________________________
# expanded_conv_7_expand_BN (Batc (None, 12, 12, 384)  1536        expanded_conv_7_expand[0][0]
# __________________________________________________________________________________________________
# expanded_conv_7_expand_relu (Ac (None, 12, 12, 384)  0           expanded_conv_7_expand_BN[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 12, 12, 384)  0           expanded_conv_7_expand_relu[0][0]
# __________________________________________________________________________________________________
# expanded_conv_7_depthwise (Dept (None, 12, 12, 384)  3456        dropout_8[0][0]
# __________________________________________________________________________________________________
# expanded_conv_7_depthwise_BN (B (None, 12, 12, 384)  1536        expanded_conv_7_depthwise[0][0]
# __________________________________________________________________________________________________
# expanded_conv_7_depthwise_relu  (None, 12, 12, 384)  0           expanded_conv_7_depthwise_BN[0][0
# __________________________________________________________________________________________________
# expanded_conv_7_project (Conv2D (None, 12, 12, 64)   24576       expanded_conv_7_depthwise_relu[0]
# __________________________________________________________________________________________________
# expanded_conv_7_project_BN (Bat (None, 12, 12, 64)   256         expanded_conv_7_project[0][0]
# __________________________________________________________________________________________________
# expanded_conv_7_add (Add)       (None, 12, 12, 64)   0           expanded_conv_6_project_BN[0][0]
#                                                                  expanded_conv_7_project_BN[0][0]
# __________________________________________________________________________________________________
# expanded_conv_8_expand (Conv2D) (None, 12, 12, 384)  24576       expanded_conv_7_add[0][0]
# __________________________________________________________________________________________________
# expanded_conv_8_expand_BN (Batc (None, 12, 12, 384)  1536        expanded_conv_8_expand[0][0]
# __________________________________________________________________________________________________
# expanded_conv_8_expand_relu (Ac (None, 12, 12, 384)  0           expanded_conv_8_expand_BN[0][0]
# __________________________________________________________________________________________________
# dropout_9 (Dropout)             (None, 12, 12, 384)  0           expanded_conv_8_expand_relu[0][0]
# __________________________________________________________________________________________________
# expanded_conv_8_depthwise (Dept (None, 12, 12, 384)  3456        dropout_9[0][0]
# __________________________________________________________________________________________________
# expanded_conv_8_depthwise_BN (B (None, 12, 12, 384)  1536        expanded_conv_8_depthwise[0][0]
# __________________________________________________________________________________________________
# expanded_conv_8_depthwise_relu  (None, 12, 12, 384)  0           expanded_conv_8_depthwise_BN[0][0
# __________________________________________________________________________________________________
# expanded_conv_8_project (Conv2D (None, 12, 12, 64)   24576       expanded_conv_8_depthwise_relu[0]
# __________________________________________________________________________________________________
# expanded_conv_8_project_BN (Bat (None, 12, 12, 64)   256         expanded_conv_8_project[0][0]
# __________________________________________________________________________________________________
# expanded_conv_8_add (Add)       (None, 12, 12, 64)   0           expanded_conv_7_add[0][0]
#                                                                  expanded_conv_8_project_BN[0][0]
# __________________________________________________________________________________________________
# expanded_conv_9_expand (Conv2D) (None, 12, 12, 384)  24576       expanded_conv_8_add[0][0]
# __________________________________________________________________________________________________
# expanded_conv_9_expand_BN (Batc (None, 12, 12, 384)  1536        expanded_conv_9_expand[0][0]
# __________________________________________________________________________________________________
# expanded_conv_9_expand_relu (Ac (None, 12, 12, 384)  0           expanded_conv_9_expand_BN[0][0]
# __________________________________________________________________________________________________
# dropout_10 (Dropout)            (None, 12, 12, 384)  0           expanded_conv_9_expand_relu[0][0]
# __________________________________________________________________________________________________
# expanded_conv_9_depthwise (Dept (None, 12, 12, 384)  3456        dropout_10[0][0]
# __________________________________________________________________________________________________
# expanded_conv_9_depthwise_BN (B (None, 12, 12, 384)  1536        expanded_conv_9_depthwise[0][0]
# __________________________________________________________________________________________________
# expanded_conv_9_depthwise_relu  (None, 12, 12, 384)  0           expanded_conv_9_depthwise_BN[0][0
# __________________________________________________________________________________________________
# expanded_conv_9_project (Conv2D (None, 12, 12, 64)   24576       expanded_conv_9_depthwise_relu[0]
# __________________________________________________________________________________________________
# expanded_conv_9_project_BN (Bat (None, 12, 12, 64)   256         expanded_conv_9_project[0][0]
# __________________________________________________________________________________________________
# expanded_conv_9_add (Add)       (None, 12, 12, 64)   0           expanded_conv_8_add[0][0]
#                                                                  expanded_conv_9_project_BN[0][0]
# __________________________________________________________________________________________________
# expanded_conv_10_expand (Conv2D (None, 12, 12, 384)  24576       expanded_conv_9_add[0][0]
# __________________________________________________________________________________________________
# expanded_conv_10_expand_BN (Bat (None, 12, 12, 384)  1536        expanded_conv_10_expand[0][0]
# __________________________________________________________________________________________________
# expanded_conv_10_expand_relu (A (None, 12, 12, 384)  0           expanded_conv_10_expand_BN[0][0]
# __________________________________________________________________________________________________
# dropout_11 (Dropout)            (None, 12, 12, 384)  0           expanded_conv_10_expand_relu[0][0
# __________________________________________________________________________________________________
# expanded_conv_10_depthwise (Dep (None, 12, 12, 384)  3456        dropout_11[0][0]
# __________________________________________________________________________________________________
# expanded_conv_10_depthwise_BN ( (None, 12, 12, 384)  1536        expanded_conv_10_depthwise[0][0]
# __________________________________________________________________________________________________
# expanded_conv_10_depthwise_relu (None, 12, 12, 384)  0           expanded_conv_10_depthwise_BN[0][
# __________________________________________________________________________________________________
# expanded_conv_10_project (Conv2 (None, 12, 12, 96)   36864       expanded_conv_10_depthwise_relu[0
# __________________________________________________________________________________________________
# expanded_conv_10_project_BN (Ba (None, 12, 12, 96)   384         expanded_conv_10_project[0][0]
# __________________________________________________________________________________________________
# expanded_conv_11_expand (Conv2D (None, 12, 12, 576)  55296       expanded_conv_10_project_BN[0][0]
# __________________________________________________________________________________________________
# expanded_conv_11_expand_BN (Bat (None, 12, 12, 576)  2304        expanded_conv_11_expand[0][0]
# __________________________________________________________________________________________________
# expanded_conv_11_expand_relu (A (None, 12, 12, 576)  0           expanded_conv_11_expand_BN[0][0]
# __________________________________________________________________________________________________
# dropout_12 (Dropout)            (None, 12, 12, 576)  0           expanded_conv_11_expand_relu[0][0
# __________________________________________________________________________________________________
# expanded_conv_11_depthwise (Dep (None, 12, 12, 576)  5184        dropout_12[0][0]
# __________________________________________________________________________________________________
# expanded_conv_11_depthwise_BN ( (None, 12, 12, 576)  2304        expanded_conv_11_depthwise[0][0]
# __________________________________________________________________________________________________
# expanded_conv_11_depthwise_relu (None, 12, 12, 576)  0           expanded_conv_11_depthwise_BN[0][
# __________________________________________________________________________________________________
# expanded_conv_11_project (Conv2 (None, 12, 12, 96)   55296       expanded_conv_11_depthwise_relu[0
# __________________________________________________________________________________________________
# expanded_conv_11_project_BN (Ba (None, 12, 12, 96)   384         expanded_conv_11_project[0][0]
# __________________________________________________________________________________________________
# expanded_conv_11_add (Add)      (None, 12, 12, 96)   0           expanded_conv_10_project_BN[0][0]
#                                                                  expanded_conv_11_project_BN[0][0]
# __________________________________________________________________________________________________
# expanded_conv_12_expand (Conv2D (None, 12, 12, 576)  55296       expanded_conv_11_add[0][0]
# __________________________________________________________________________________________________
# expanded_conv_12_expand_BN (Bat (None, 12, 12, 576)  2304        expanded_conv_12_expand[0][0]
# __________________________________________________________________________________________________
# expanded_conv_12_expand_relu (A (None, 12, 12, 576)  0           expanded_conv_12_expand_BN[0][0]
# __________________________________________________________________________________________________
# dropout_13 (Dropout)            (None, 12, 12, 576)  0           expanded_conv_12_expand_relu[0][0
# __________________________________________________________________________________________________
# expanded_conv_12_depthwise (Dep (None, 12, 12, 576)  5184        dropout_13[0][0]
# __________________________________________________________________________________________________
# expanded_conv_12_depthwise_BN ( (None, 12, 12, 576)  2304        expanded_conv_12_depthwise[0][0]
# __________________________________________________________________________________________________
# expanded_conv_12_depthwise_relu (None, 12, 12, 576)  0           expanded_conv_12_depthwise_BN[0][
# __________________________________________________________________________________________________
# expanded_conv_12_project (Conv2 (None, 12, 12, 96)   55296       expanded_conv_12_depthwise_relu[0
# __________________________________________________________________________________________________
# expanded_conv_12_project_BN (Ba (None, 12, 12, 96)   384         expanded_conv_12_project[0][0]
# __________________________________________________________________________________________________
# expanded_conv_12_add (Add)      (None, 12, 12, 96)   0           expanded_conv_11_add[0][0]
#                                                                  expanded_conv_12_project_BN[0][0]
# __________________________________________________________________________________________________
# expanded_conv_13_expand (Conv2D (None, 12, 12, 576)  55296       expanded_conv_12_add[0][0]
# __________________________________________________________________________________________________
# expanded_conv_13_expand_BN (Bat (None, 12, 12, 576)  2304        expanded_conv_13_expand[0][0]
# __________________________________________________________________________________________________
# expanded_conv_13_expand_relu (A (None, 12, 12, 576)  0           expanded_conv_13_expand_BN[0][0]
# __________________________________________________________________________________________________
# dropout_14 (Dropout)            (None, 12, 12, 576)  0           expanded_conv_13_expand_relu[0][0
# __________________________________________________________________________________________________
# expanded_conv_13_depthwise (Dep (None, 12, 12, 576)  5184        dropout_14[0][0]
# __________________________________________________________________________________________________
# expanded_conv_13_depthwise_BN ( (None, 12, 12, 576)  2304        expanded_conv_13_depthwise[0][0]
# __________________________________________________________________________________________________
# expanded_conv_13_depthwise_relu (None, 12, 12, 576)  0           expanded_conv_13_depthwise_BN[0][
# __________________________________________________________________________________________________
# expanded_conv_13_project (Conv2 (None, 12, 12, 160)  92160       expanded_conv_13_depthwise_relu[0
# __________________________________________________________________________________________________
# expanded_conv_13_project_BN (Ba (None, 12, 12, 160)  640         expanded_conv_13_project[0][0]
# __________________________________________________________________________________________________
# expanded_conv_14_expand (Conv2D (None, 12, 12, 960)  153600      expanded_conv_13_project_BN[0][0]
# __________________________________________________________________________________________________
# expanded_conv_14_expand_BN (Bat (None, 12, 12, 960)  3840        expanded_conv_14_expand[0][0]
# __________________________________________________________________________________________________
# expanded_conv_14_expand_relu (A (None, 12, 12, 960)  0           expanded_conv_14_expand_BN[0][0]
# __________________________________________________________________________________________________
# dropout_15 (Dropout)            (None, 12, 12, 960)  0           expanded_conv_14_expand_relu[0][0
# __________________________________________________________________________________________________
# expanded_conv_14_depthwise (Dep (None, 12, 12, 960)  8640        dropout_15[0][0]
# __________________________________________________________________________________________________
# expanded_conv_14_depthwise_BN ( (None, 12, 12, 960)  3840        expanded_conv_14_depthwise[0][0]
# __________________________________________________________________________________________________
# expanded_conv_14_depthwise_relu (None, 12, 12, 960)  0           expanded_conv_14_depthwise_BN[0][
# __________________________________________________________________________________________________
# expanded_conv_14_project (Conv2 (None, 12, 12, 160)  153600      expanded_conv_14_depthwise_relu[0
# __________________________________________________________________________________________________
# expanded_conv_14_project_BN (Ba (None, 12, 12, 160)  640         expanded_conv_14_project[0][0]
# __________________________________________________________________________________________________
# expanded_conv_14_add (Add)      (None, 12, 12, 160)  0           expanded_conv_13_project_BN[0][0]
#                                                                  expanded_conv_14_project_BN[0][0]
# __________________________________________________________________________________________________
# expanded_conv_15_expand (Conv2D (None, 12, 12, 960)  153600      expanded_conv_14_add[0][0]
# __________________________________________________________________________________________________
# expanded_conv_15_expand_BN (Bat (None, 12, 12, 960)  3840        expanded_conv_15_expand[0][0]
# __________________________________________________________________________________________________
# expanded_conv_15_expand_relu (A (None, 12, 12, 960)  0           expanded_conv_15_expand_BN[0][0]
# __________________________________________________________________________________________________
# dropout_16 (Dropout)            (None, 12, 12, 960)  0           expanded_conv_15_expand_relu[0][0
# __________________________________________________________________________________________________
# expanded_conv_15_depthwise (Dep (None, 12, 12, 960)  8640        dropout_16[0][0]
# __________________________________________________________________________________________________
# expanded_conv_15_depthwise_BN ( (None, 12, 12, 960)  3840        expanded_conv_15_depthwise[0][0]
# __________________________________________________________________________________________________
# expanded_conv_15_depthwise_relu (None, 12, 12, 960)  0           expanded_conv_15_depthwise_BN[0][
# __________________________________________________________________________________________________
# expanded_conv_15_project (Conv2 (None, 12, 12, 160)  153600      expanded_conv_15_depthwise_relu[0
# __________________________________________________________________________________________________
# expanded_conv_15_project_BN (Ba (None, 12, 12, 160)  640         expanded_conv_15_project[0][0]
# __________________________________________________________________________________________________
# expanded_conv_15_add (Add)      (None, 12, 12, 160)  0           expanded_conv_14_add[0][0]
#                                                                  expanded_conv_15_project_BN[0][0]
# __________________________________________________________________________________________________
# expanded_conv_16_expand (Conv2D (None, 12, 12, 960)  153600      expanded_conv_15_add[0][0]
# __________________________________________________________________________________________________
# expanded_conv_16_expand_BN (Bat (None, 12, 12, 960)  3840        expanded_conv_16_expand[0][0]
# __________________________________________________________________________________________________
# expanded_conv_16_expand_relu (A (None, 12, 12, 960)  0           expanded_conv_16_expand_BN[0][0]
# __________________________________________________________________________________________________
# dropout_17 (Dropout)            (None, 12, 12, 960)  0           expanded_conv_16_expand_relu[0][0
# __________________________________________________________________________________________________
# expanded_conv_16_depthwise (Dep (None, 12, 12, 960)  8640        dropout_17[0][0]
# __________________________________________________________________________________________________
# expanded_conv_16_depthwise_BN ( (None, 12, 12, 960)  3840        expanded_conv_16_depthwise[0][0]
# __________________________________________________________________________________________________
# expanded_conv_16_depthwise_relu (None, 12, 12, 960)  0           expanded_conv_16_depthwise_BN[0][
# __________________________________________________________________________________________________
# expanded_conv_16_project (Conv2 (None, 12, 12, 320)  307200      expanded_conv_16_depthwise_relu[0
# __________________________________________________________________________________________________
# expanded_conv_16_project_BN (Ba (None, 12, 12, 320)  1280        expanded_conv_16_project[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_2 (AveragePoo (None, 1, 1, 320)    0           expanded_conv_16_project_BN[0][0]
# __________________________________________________________________________________________________
# image_pooling (Conv2D)          (None, 1, 1, 256)    81920       average_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# image_pooling_BN (BatchNormaliz (None, 1, 1, 256)    1024        image_pooling[0][0]
# __________________________________________________________________________________________________
# aspp0 (Conv2D)                  (None, 12, 12, 256)  81920       expanded_conv_16_project_BN[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 1, 1, 256)    0           image_pooling_BN[0][0]
# __________________________________________________________________________________________________
# aspp0_BN (BatchNormalization)   (None, 12, 12, 256)  1024        aspp0[0][0]
# __________________________________________________________________________________________________
# bilinear_upsampling_3 (Bilinear (None, 12, 12, 256)  0           activation_3[0][0]
# __________________________________________________________________________________________________
# aspp0_activation (Activation)   (None, 12, 12, 256)  0           aspp0_BN[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 12, 12, 512)  0           bilinear_upsampling_3[0][0]
#                                                                  aspp0_activation[0][0]
# __________________________________________________________________________________________________
# concat_projection (Conv2D)      (None, 12, 12, 256)  131072      concatenate_2[0][0]
# __________________________________________________________________________________________________
# concat_projection_BN (BatchNorm (None, 12, 12, 256)  1024        concat_projection[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 12, 12, 256)  0           concat_projection_BN[0][0]
# __________________________________________________________________________________________________
# dropout_18 (Dropout)            (None, 12, 12, 256)  0           activation_4[0][0]
# __________________________________________________________________________________________________
# custom_logits_semantic (Conv2D) (None, 12, 12, 1)    257         dropout_18[0][0]
# __________________________________________________________________________________________________
# bilinear_upsampling_4 (Bilinear (None, 96, 96, 1)    0           custom_logits_semantic[0][0]
# ==================================================================================================
# Total params: 2,140,929
# Trainable params: 2,107,841
# Non-trainable params: 33,088
# __________________________________________________________________________________________________
# None

# %%
import os
import numpy as np
import keras
import matplotlib.pyplot as plt

from skimage.transform import resize

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
K.set_image_data_format('channels_last')  # TF dimension ordering in this code

create_image_rows = 420
create_image_cols = 580

smooth = 1.0

# %%
image_t = np.load('/content/gdrive/My Drive/Colab Notebooks/ultrasound_neck_nerve_seg/image_T.npy')
mask_t = np.load('/content/gdrive/My Drive/Colab Notebooks/ultrasound_neck_nerve_seg/mask_T.npy')

# %%
train_image_rows = 96
train_image_cols = 96

def preprocess(imgs):
    imgs_p = np.ndarray(
        (imgs.shape[0], train_image_rows, train_image_cols), dtype=np.uint8)
    for i in range(imgs.shape[0]):
        imgs_p[i] = resize(
            imgs[i], (train_image_rows, train_image_cols), preserve_range=True)

    imgs_p = imgs_p[..., np.newaxis]
    return imgs_p

# %%
image_c = preprocess(image_t)
mask_c = preprocess(mask_t)

image_c = image_c.astype('float32')

mean = np.mean(image_c)  # mean for data centering
std = np.std(image_c)  # std for data normalization

image_c -= mean
image_c /= std

mask_c = mask_c .astype('float32')
mask_c /= 255.  # scale masks to [0, 1]
# Out:
# /usr/local/lib/python3.6/dist-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "

# %%
def dice_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

def dice_coef_loss(y_true, y_pred):
    return -dice_coef(y_true, y_pred)

# %%
image_train = image_c[0:1858]
image_valid = image_c[1858:]

mask_train = mask_c[0:1858]
mask_valid = mask_c[1858:]

# %%
train_datagen = keras.preprocessing.image.ImageDataGenerator(
    featurewise_center=True,
    featurewise_std_normalization=True,
    zca_whitening=True ,
    zca_epsilon=1e-02,
    width_shift_range=0.2,
    height_shift_range=0.2,
    fill_mode = 'nearest',
    horizontal_flip=True)
test_datagen = keras.preprocessing.image.ImageDataGenerator()
# Out:
# /usr/local/lib/python3.6/dist-packages/keras_preprocessing/image.py:841: UserWarning: This ImageDataGenerator specifies `zca_whitening` which overrides setting of`featurewise_std_normalization`.
#   warnings.warn('This ImageDataGenerator specifies '

# %%
train_data = train_datagen.flow(image_train, mask_train,batch_size=32)
valid_data = test_datagen.flow(image_valid, mask_valid,batch_size=32)

# %%
model.compile(optimizer=keras.optimizers.Adam(lr=0.0000001),
                  loss=dice_coef_loss, metrics=[dice_coef])

# %%
print(('-'*30))
print('Fitting model...')
print(('-'*30))
from keras.callbacks import EarlyStopping, TensorBoard
early_stopping = EarlyStopping(monitor='val_loss', min_delta=0, patience=5, verbose=1, mode='auto')
tb_hist = TensorBoard(log_dir='./logs', 
                      histogram_freq=0, write_grads=True, write_images=True)

history = model.fit_generator(train_data,steps_per_epoch=100, epochs=200, verbose=1, shuffle=True,
                   validation_data=valid_data, validation_steps=500 ,callbacks=[tb_hist,early_stopping])

print(('-'*30))
print('Done !!')
print(('-'*30))
# Out:
# ------------------------------
# Fitting model...
# ------------------------------
# Epoch 1/200
# /usr/local/lib/python3.6/dist-packages/keras_preprocessing/image.py:1131: UserWarning: This ImageDataGenerator specifies `featurewise_center`, but it hasn't been fit on any training data. Fit it first by calling `.fit(numpy_data)`.
#   warnings.warn('This ImageDataGenerator specifies '
# /usr/local/lib/python3.6/dist-packages/keras_preprocessing/image.py:1150: UserWarning: This ImageDataGenerator specifies `zca_whitening`, but it hasn't been fit on any training data. Fit it first by calling `.fit(numpy_data)`.
#   warnings.warn('This ImageDataGenerator specifies '
# 100/100 [==============================] - 79s 786ms/step - loss: -0.0826 - dice_coef: 0.0826 - val_loss: -0.0596 - val_dice_coef: 0.0596
# Epoch 2/200
# 100/100 [==============================] - 69s 688ms/step - loss: -0.0826 - dice_coef: 0.0826 - val_loss: -0.0596 - val_dice_coef: 0.0596
# Epoch 3/200
# 100/100 [==============================] - 69s 690ms/step - loss: -0.0838 - dice_coef: 0.0838 - val_loss: -0.0596 - val_dice_coef: 0.0596
# Epoch 4/200
# 100/100 [==============================] - 69s 687ms/step - loss: -0.0856 - dice_coef: 0.0856 - val_loss: -0.0597 - val_dice_coef: 0.0597
# Epoch 5/200
# 100/100 [==============================] - 68s 684ms/step - loss: -0.0859 - dice_coef: 0.0859 - val_loss: -0.0597 - val_dice_coef: 0.0597
# Epoch 6/200
# 100/100 [==============================] - 68s 685ms/step - loss: -0.0866 - dice_coef: 0.0866 - val_loss: -0.0598 - val_dice_coef: 0.0598
# Epoch 7/200
# 100/100 [==============================] - 69s 686ms/step - loss: -0.0888 - dice_coef: 0.0888 - val_loss: -0.0598 - val_dice_coef: 0.0598
# Epoch 8/200
# 100/100 [==============================] - 68s 685ms/step - loss: -0.0893 - dice_coef: 0.0893 - val_loss: -0.0599 - val_dice_coef: 0.0599
# Epoch 9/200
# 100/100 [==============================] - 68s 685ms/step - loss: -0.0908 - dice_coef: 0.0908 - val_loss: -0.0600 - val_dice_coef: 0.0600
# Epoch 10/200
# 100/100 [==============================] - 69s 687ms/step - loss: -0.0914 - dice_coef: 0.0914 - val_loss: -0.0600 - val_dice_coef: 0.0600
# Epoch 11/200
# 100/100 [==============================] - 69s 687ms/step - loss: -0.0934 - dice_coef: 0.0934 - val_loss: -0.0600 - val_dice_coef: 0.0600
# Epoch 12/200
# 100/100 [==============================] - 69s 687ms/step - loss: -0.0933 - dice_coef: 0.0933 - val_loss: -0.0600 - val_dice_coef: 0.0600
# Epoch 13/200
# 100/100 [==============================] - 69s 687ms/step - loss: -0.0942 - dice_coef: 0.0942 - val_loss: -0.0600 - val_dice_coef: 0.0600
# Epoch 14/200
# 100/100 [==============================] - 69s 691ms/step - loss: -0.0963 - dice_coef: 0.0963 - val_loss: -0.0602 - val_dice_coef: 0.0602
# Epoch 15/200
# 100/100 [==============================] - 69s 688ms/step - loss: -0.0961 - dice_coef: 0.0961 - val_loss: -0.0603 - val_dice_coef: 0.0603
# Epoch 16/200
# 100/100 [==============================] - 69s 689ms/step - loss: -0.0979 - dice_coef: 0.0979 - val_loss: -0.0603 - val_dice_coef: 0.0603
# Epoch 17/200
# 100/100 [==============================] - 69s 689ms/step - loss: -0.0999 - dice_coef: 0.0999 - val_loss: -0.0604 - val_dice_coef: 0.0604
# Epoch 18/200
# 100/100 [==============================] - 69s 687ms/step - loss: -0.1013 - dice_coef: 0.1013 - val_loss: -0.0604 - val_dice_coef: 0.0604
# Epoch 19/200
# 100/100 [==============================] - 69s 687ms/step - loss: -0.1009 - dice_coef: 0.1009 - val_loss: -0.0604 - val_dice_coef: 0.0604
# Epoch 20/200
# 100/100 [==============================] - 69s 688ms/step - loss: -0.1029 - dice_coef: 0.1029 - val_loss: -0.0605 - val_dice_coef: 0.0605
# Epoch 21/200
# 100/100 [==============================] - 69s 687ms/step - loss: -0.1038 - dice_coef: 0.1038 - val_loss: -0.0605 - val_dice_coef: 0.0605
# Epoch 22/200
# 100/100 [==============================] - 69s 687ms/step - loss: -0.1053 - dice_coef: 0.1053 - val_loss: -0.0606 - val_dice_coef: 0.0606
# Epoch 23/200
# 100/100 [==============================] - 69s 689ms/step - loss: -0.1068 - dice_coef: 0.1068 - val_loss: -0.0607 - val_dice_coef: 0.0607
# Epoch 24/200
# 100/100 [==============================] - 69s 686ms/step - loss: -0.1081 - dice_coef: 0.1081 - val_loss: -0.0607 - val_dice_coef: 0.0607
# Epoch 25/200
# 100/100 [==============================] - 69s 687ms/step - loss: -0.1110 - dice_coef: 0.1110 - val_loss: -0.0608 - val_dice_coef: 0.0608
# Epoch 26/200
# 100/100 [==============================] - 69s 687ms/step - loss: -0.1099 - dice_coef: 0.1099 - val_loss: -0.0607 - val_dice_coef: 0.0607
# Epoch 27/200
# 100/100 [==============================] - 69s 688ms/step - loss: -0.1113 - dice_coef: 0.1113 - val_loss: -0.0608 - val_dice_coef: 0.0608
# Epoch 28/200
# 100/100 [==============================] - 69s 686ms/step - loss: -0.1135 - dice_coef: 0.1135 - val_loss: -0.0609 - val_dice_coef: 0.0609
# Epoch 29/200
# 100/100 [==============================] - 69s 688ms/step - loss: -0.1117 - dice_coef: 0.1117 - val_loss: -0.0610 - val_dice_coef: 0.0610
# Epoch 30/200
# 100/100 [==============================] - 69s 690ms/step - loss: -0.1147 - dice_coef: 0.1147 - val_loss: -0.0611 - val_dice_coef: 0.0611
# Epoch 31/200
# 100/100 [==============================] - 68s 685ms/step - loss: -0.1157 - dice_coef: 0.1157 - val_loss: -0.0611 - val_dice_coef: 0.0611
# Epoch 32/200
# 100/100 [==============================] - 69s 686ms/step - loss: -0.1170 - dice_coef: 0.1170 - val_loss: -0.0611 - val_dice_coef: 0.0611
# Epoch 33/200
# 100/100 [==============================] - 69s 687ms/step - loss: -0.1178 - dice_coef: 0.1178 - val_loss: -0.0612 - val_dice_coef: 0.0612
# Epoch 34/200
# 100/100 [==============================] - 69s 686ms/step - loss: -0.1202 - dice_coef: 0.1202 - val_loss: -0.0613 - val_dice_coef: 0.0613
# Epoch 35/200
# 100/100 [==============================] - 69s 686ms/step - loss: -0.1200 - dice_coef: 0.1200 - val_loss: -0.0613 - val_dice_coef: 0.0613
# Epoch 36/200
# 100/100 [==============================] - 69s 687ms/step - loss: -0.1218 - dice_coef: 0.1218 - val_loss: -0.0614 - val_dice_coef: 0.0614
# Epoch 37/200
# 100/100 [==============================] - 69s 691ms/step - loss: -0.1222 - dice_coef: 0.1222 - val_loss: -0.0614 - val_dice_coef: 0.0614
# Epoch 38/200
# 100/100 [==============================] - 69s 686ms/step - loss: -0.1260 - dice_coef: 0.1260 - val_loss: -0.0614 - val_dice_coef: 0.0614
# Epoch 39/200
# 100/100 [==============================] - 69s 688ms/step - loss: -0.1253 - dice_coef: 0.1253 - val_loss: -0.0616 - val_dice_coef: 0.0616
# Epoch 40/200
# 100/100 [==============================] - 69s 692ms/step - loss: -0.1281 - dice_coef: 0.1281 - val_loss: -0.0615 - val_dice_coef: 0.0615
# Epoch 41/200
# 100/100 [==============================] - 69s 688ms/step - loss: -0.1303 - dice_coef: 0.1303 - val_loss: -0.0616 - val_dice_coef: 0.0616
# Epoch 42/200
# 100/100 [==============================] - 68s 683ms/step - loss: -0.1316 - dice_coef: 0.1316 - val_loss: -0.0616 - val_dice_coef: 0.0616
# Epoch 43/200
# 100/100 [==============================] - 69s 688ms/step - loss: -0.1313 - dice_coef: 0.1313 - val_loss: -0.0618 - val_dice_coef: 0.0618
# Epoch 44/200
# 100/100 [==============================] - 69s 688ms/step - loss: -0.1322 - dice_coef: 0.1322 - val_loss: -0.0618 - val_dice_coef: 0.0618
# Epoch 45/200
# 100/100 [==============================] - 69s 687ms/step - loss: -0.1350 - dice_coef: 0.1350 - val_loss: -0.0617 - val_dice_coef: 0.0617
# Epoch 46/200
# 100/100 [==============================] - 69s 690ms/step - loss: -0.1364 - dice_coef: 0.1364 - val_loss: -0.0619 - val_dice_coef: 0.0619
# Epoch 47/200
# 100/100 [==============================] - 68s 684ms/step - loss: -0.1381 - dice_coef: 0.1381 - val_loss: -0.0620 - val_dice_coef: 0.0620
# Epoch 48/200
# 100/100 [==============================] - 68s 684ms/step - loss: -0.1382 - dice_coef: 0.1382 - val_loss: -0.0621 - val_dice_coef: 0.0621
# Epoch 49/200
# 100/100 [==============================] - 69s 685ms/step - loss: -0.1414 - dice_coef: 0.1414 - val_loss: -0.0622 - val_dice_coef: 0.0622
# Epoch 50/200
# 100/100 [==============================] - 68s 685ms/step - loss: -0.1415 - dice_coef: 0.1415 - val_loss: -0.0621 - val_dice_coef: 0.0621
# Epoch 51/200
# 100/100 [==============================] - 68s 684ms/step - loss: -0.1424 - dice_coef: 0.1424 - val_loss: -0.0621 - val_dice_coef: 0.0621
# Epoch 52/200
# 100/100 [==============================] - 69s 686ms/step - loss: -0.1435 - dice_coef: 0.1435 - val_loss: -0.0622 - val_dice_coef: 0.0622
# Epoch 53/200
# 100/100 [==============================] - 68s 685ms/step - loss: -0.1463 - dice_coef: 0.1463 - val_loss: -0.0623 - val_dice_coef: 0.0623
# Epoch 54/200
# 100/100 [==============================] - 68s 684ms/step - loss: -0.1445 - dice_coef: 0.1445 - val_loss: -0.0624 - val_dice_coef: 0.0624
# Epoch 55/200
# 100/100 [==============================] - 68s 684ms/step - loss: -0.1474 - dice_coef: 0.1474 - val_loss: -0.0625 - val_dice_coef: 0.0625
# Epoch 56/200
# 100/100 [==============================] - 69s 685ms/step - loss: -0.1499 - dice_coef: 0.1499 - val_loss: -0.0626 - val_dice_coef: 0.0626
# Epoch 57/200
# 100/100 [==============================] - 69s 690ms/step - loss: -0.1497 - dice_coef: 0.1497 - val_loss: -0.0626 - val_dice_coef: 0.0626
# Epoch 58/200
# 100/100 [==============================] - 69s 689ms/step - loss: -0.1520 - dice_coef: 0.1520 - val_loss: -0.0627 - val_dice_coef: 0.0627
# Epoch 59/200
# 100/100 [==============================] - 69s 687ms/step - loss: -0.1539 - dice_coef: 0.1539 - val_loss: -0.0627 - val_dice_coef: 0.0627
# Epoch 60/200
# 100/100 [==============================] - 69s 689ms/step - loss: -0.1550 - dice_coef: 0.1550 - val_loss: -0.0628 - val_dice_coef: 0.0628
# Epoch 61/200
# 100/100 [==============================] - 69s 687ms/step - loss: -0.1563 - dice_coef: 0.1563 - val_loss: -0.0630 - val_dice_coef: 0.0630
# Epoch 62/200
# 100/100 [==============================] - 69s 687ms/step - loss: -0.1575 - dice_coef: 0.1575 - val_loss: -0.0630 - val_dice_coef: 0.0630
# Epoch 63/200
# 100/100 [==============================] - 69s 688ms/step - loss: -0.1598 - dice_coef: 0.1598 - val_loss: -0.0631 - val_dice_coef: 0.0631
# Epoch 64/200
# 100/100 [==============================] - 69s 685ms/step - loss: -0.1599 - dice_coef: 0.1599 - val_loss: -0.0631 - val_dice_coef: 0.0631
# Epoch 65/200
# 100/100 [==============================] - 69s 687ms/step - loss: -0.1612 - dice_coef: 0.1612 - val_loss: -0.0631 - val_dice_coef: 0.0631
# Epoch 66/200
# 100/100 [==============================] - 69s 688ms/step - loss: -0.1641 - dice_coef: 0.1641 - val_loss: -0.0632 - val_dice_coef: 0.0632
# Epoch 67/200
# 100/100 [==============================] - 69s 687ms/step - loss: -0.1666 - dice_coef: 0.1666 - val_loss: -0.0633 - val_dice_coef: 0.0633
# Epoch 68/200
# 100/100 [==============================] - 69s 686ms/step - loss: -0.1671 - dice_coef: 0.1671 - val_loss: -0.0632 - val_dice_coef: 0.0632
# Epoch 69/200
# 100/100 [==============================] - 69s 688ms/step - loss: -0.1687 - dice_coef: 0.1687 - val_loss: -0.0634 - val_dice_coef: 0.0634
# Epoch 70/200
# 100/100 [==============================] - 69s 686ms/step - loss: -0.1719 - dice_coef: 0.1719 - val_loss: -0.0634 - val_dice_coef: 0.0634
# Epoch 71/200
# 100/100 [==============================] - 69s 687ms/step - loss: -0.1707 - dice_coef: 0.1707 - val_loss: -0.0636 - val_dice_coef: 0.0636
# Epoch 72/200
# 100/100 [==============================] - 69s 688ms/step - loss: -0.1752 - dice_coef: 0.1752 - val_loss: -0.0639 - val_dice_coef: 0.0639
# Epoch 73/200
# 100/100 [==============================] - 69s 687ms/step - loss: -0.1762 - dice_coef: 0.1762 - val_loss: -0.0638 - val_dice_coef: 0.0638
# Epoch 74/200
# 100/100 [==============================] - 69s 687ms/step - loss: -0.1764 - dice_coef: 0.1764 - val_loss: -0.0638 - val_dice_coef: 0.0638
# Epoch 75/200
# 100/100 [==============================] - 69s 687ms/step - loss: -0.1788 - dice_coef: 0.1788 - val_loss: -0.0640 - val_dice_coef: 0.0640
# Epoch 76/200
# 100/100 [==============================] - 69s 688ms/step - loss: -0.1796 - dice_coef: 0.1796 - val_loss: -0.0641 - val_dice_coef: 0.0641
# Epoch 77/200
# 100/100 [==============================] - 69s 687ms/step - loss: -0.1825 - dice_coef: 0.1825 - val_loss: -0.0642 - val_dice_coef: 0.0642
# Epoch 78/200
# 100/100 [==============================] - 68s 685ms/step - loss: -0.1833 - dice_coef: 0.1833 - val_loss: -0.0642 - val_dice_coef: 0.0642
# Epoch 79/200
# 100/100 [==============================] - 69s 686ms/step - loss: -0.1847 - dice_coef: 0.1847 - val_loss: -0.0642 - val_dice_coef: 0.0642
# Epoch 80/200
# 100/100 [==============================] - 69s 685ms/step - loss: -0.1860 - dice_coef: 0.1860 - val_loss: -0.0642 - val_dice_coef: 0.0642
# Epoch 81/200
# 100/100 [==============================] - 68s 684ms/step - loss: -0.1880 - dice_coef: 0.1880 - val_loss: -0.0643 - val_dice_coef: 0.0643
# Epoch 82/200
# 100/100 [==============================] - 69s 687ms/step - loss: -0.1893 - dice_coef: 0.1893 - val_loss: -0.0644 - val_dice_coef: 0.0644
# Epoch 83/200
# 100/100 [==============================] - 69s 685ms/step - loss: -0.1916 - dice_coef: 0.1916 - val_loss: -0.0647 - val_dice_coef: 0.0647
# Epoch 84/200
# 100/100 [==============================] - 68s 684ms/step - loss: -0.1914 - dice_coef: 0.1914 - val_loss: -0.0647 - val_dice_coef: 0.0647
# Epoch 85/200
# 100/100 [==============================] - 68s 684ms/step - loss: -0.1957 - dice_coef: 0.1957 - val_loss: -0.0648 - val_dice_coef: 0.0648
# Epoch 86/200
# 100/100 [==============================] - 69s 688ms/step - loss: -0.1970 - dice_coef: 0.1970 - val_loss: -0.0649 - val_dice_coef: 0.0649
# Epoch 87/200
# 100/100 [==============================] - 69s 686ms/step - loss: -0.2004 - dice_coef: 0.2004 - val_loss: -0.0650 - val_dice_coef: 0.0650
# Epoch 88/200
# 100/100 [==============================] - 69s 695ms/step - loss: -0.1982 - dice_coef: 0.1982 - val_loss: -0.0653 - val_dice_coef: 0.0653
# Epoch 89/200
# 100/100 [==============================] - 69s 688ms/step - loss: -0.2023 - dice_coef: 0.2023 - val_loss: -0.0652 - val_dice_coef: 0.0652
# Epoch 90/200
# 100/100 [==============================] - 69s 686ms/step - loss: -0.2044 - dice_coef: 0.2044 - val_loss: -0.0652 - val_dice_coef: 0.0652
# Epoch 91/200
# 100/100 [==============================] - 68s 684ms/step - loss: -0.2044 - dice_coef: 0.2044 - val_loss: -0.0652 - val_dice_coef: 0.0652
# Epoch 92/200
# 100/100 [==============================] - 69s 686ms/step - loss: -0.2070 - dice_coef: 0.2070 - val_loss: -0.0653 - val_dice_coef: 0.0653
# Epoch 93/200
# 100/100 [==============================] - 68s 684ms/step - loss: -0.2082 - dice_coef: 0.2082 - val_loss: -0.0656 - val_dice_coef: 0.0656
# Epoch 94/200
# 100/100 [==============================] - 69s 686ms/step - loss: -0.2099 - dice_coef: 0.2099 - val_loss: -0.0657 - val_dice_coef: 0.0657
# Epoch 95/200
# 100/100 [==============================] - 69s 685ms/step - loss: -0.2140 - dice_coef: 0.2140 - val_loss: -0.0656 - val_dice_coef: 0.0656
# Epoch 96/200
# 100/100 [==============================] - 69s 687ms/step - loss: -0.2139 - dice_coef: 0.2139 - val_loss: -0.0657 - val_dice_coef: 0.0657
# Epoch 97/200
# 100/100 [==============================] - 69s 693ms/step - loss: -0.2192 - dice_coef: 0.2192 - val_loss: -0.0658 - val_dice_coef: 0.0658
# Epoch 98/200
# 100/100 [==============================] - 69s 688ms/step - loss: -0.2189 - dice_coef: 0.2189 - val_loss: -0.0659 - val_dice_coef: 0.0659
# Epoch 99/200
# 100/100 [==============================] - 69s 687ms/step - loss: -0.2186 - dice_coef: 0.2186 - val_loss: -0.0660 - val_dice_coef: 0.0660
# Epoch 100/200
# 100/100 [==============================] - 69s 687ms/step - loss: -0.2218 - dice_coef: 0.2218 - val_loss: -0.0664 - val_dice_coef: 0.0664
# Epoch 101/200
# 100/100 [==============================] - 69s 687ms/step - loss: -0.2218 - dice_coef: 0.2218 - val_loss: -0.0663 - val_dice_coef: 0.0663
# Epoch 102/200
# 100/100 [==============================] - 69s 687ms/step - loss: -0.2244 - dice_coef: 0.2244 - val_loss: -0.0664 - val_dice_coef: 0.0664
# Epoch 103/200
# 100/100 [==============================] - 69s 687ms/step - loss: -0.2280 - dice_coef: 0.2280 - val_loss: -0.0666 - val_dice_coef: 0.0666
# Epoch 104/200
# 100/100 [==============================] - 69s 686ms/step - loss: -0.2306 - dice_coef: 0.2306 - val_loss: -0.0666 - val_dice_coef: 0.0666
# Epoch 105/200
# 100/100 [==============================] - 69s 687ms/step - loss: -0.2308 - dice_coef: 0.2308 - val_loss: -0.0668 - val_dice_coef: 0.0668
# Epoch 106/200
# 100/100 [==============================] - 69s 687ms/step - loss: -0.2329 - dice_coef: 0.2329 - val_loss: -0.0672 - val_dice_coef: 0.0672
# Epoch 107/200
# 100/100 [==============================] - 69s 687ms/step - loss: -0.2356 - dice_coef: 0.2356 - val_loss: -0.0673 - val_dice_coef: 0.0673
# Epoch 108/200
# 100/100 [==============================] - 69s 685ms/step - loss: -0.2374 - dice_coef: 0.2374 - val_loss: -0.0674 - val_dice_coef: 0.0674
# Epoch 109/200
# 100/100 [==============================] - 69s 689ms/step - loss: -0.2396 - dice_coef: 0.2396 - val_loss: -0.0673 - val_dice_coef: 0.0673
# Epoch 110/200
# 100/100 [==============================] - 69s 687ms/step - loss: -0.2418 - dice_coef: 0.2418 - val_loss: -0.0674 - val_dice_coef: 0.0674
# Epoch 111/200
# 100/100 [==============================] - 69s 686ms/step - loss: -0.2451 - dice_coef: 0.2451 - val_loss: -0.0673 - val_dice_coef: 0.0673
# Epoch 112/200
# 100/100 [==============================] - 69s 687ms/step - loss: -0.2460 - dice_coef: 0.2460 - val_loss: -0.0676 - val_dice_coef: 0.0676
# Epoch 113/200
# 100/100 [==============================] - 69s 688ms/step - loss: -0.2480 - dice_coef: 0.2480 - val_loss: -0.0679 - val_dice_coef: 0.0679
# Epoch 114/200
# 100/100 [==============================] - 69s 686ms/step - loss: -0.2487 - dice_coef: 0.2487 - val_loss: -0.0679 - val_dice_coef: 0.0679
# Epoch 115/200
# 100/100 [==============================] - 69s 688ms/step - loss: -0.2528 - dice_coef: 0.2528 - val_loss: -0.0680 - val_dice_coef: 0.0680
# Epoch 116/200
# 100/100 [==============================] - 69s 687ms/step - loss: -0.2534 - dice_coef: 0.2534 - val_loss: -0.0683 - val_dice_coef: 0.0683
# Epoch 117/200
# 100/100 [==============================] - 69s 689ms/step - loss: -0.2562 - dice_coef: 0.2562 - val_loss: -0.0684 - val_dice_coef: 0.0684
# Epoch 118/200
# 100/100 [==============================] - 69s 690ms/step - loss: -0.2550 - dice_coef: 0.2550 - val_loss: -0.0686 - val_dice_coef: 0.0686
# Epoch 119/200
# 100/100 [==============================] - 69s 692ms/step - loss: -0.2580 - dice_coef: 0.2580 - val_loss: -0.0687 - val_dice_coef: 0.0687
# Epoch 120/200
# 100/100 [==============================] - 69s 686ms/step - loss: -0.2599 - dice_coef: 0.2599 - val_loss: -0.0687 - val_dice_coef: 0.0687
# Epoch 121/200
# 100/100 [==============================] - 69s 686ms/step - loss: -0.2630 - dice_coef: 0.2630 - val_loss: -0.0687 - val_dice_coef: 0.0687
# Epoch 122/200
# 100/100 [==============================] - 69s 687ms/step - loss: -0.2650 - dice_coef: 0.2650 - val_loss: -0.0690 - val_dice_coef: 0.0690
# Epoch 123/200
# 100/100 [==============================] - 69s 686ms/step - loss: -0.2653 - dice_coef: 0.2653 - val_loss: -0.0690 - val_dice_coef: 0.0690
# Epoch 124/200
# 100/100 [==============================] - 69s 687ms/step - loss: -0.2690 - dice_coef: 0.2690 - val_loss: -0.0691 - val_dice_coef: 0.0691
# Epoch 125/200
# 100/100 [==============================] - 69s 687ms/step - loss: -0.2734 - dice_coef: 0.2734 - val_loss: -0.0691 - val_dice_coef: 0.0691
# Epoch 126/200
# 100/100 [==============================] - 69s 687ms/step - loss: -0.2775 - dice_coef: 0.2775 - val_loss: -0.0695 - val_dice_coef: 0.0695
# Epoch 127/200
# 100/100 [==============================] - 69s 686ms/step - loss: -0.2745 - dice_coef: 0.2745 - val_loss: -0.0701 - val_dice_coef: 0.0701
# Epoch 128/200
# 100/100 [==============================] - 69s 692ms/step - loss: -0.2798 - dice_coef: 0.2798 - val_loss: -0.0701 - val_dice_coef: 0.0701
# Epoch 129/200
# 100/100 [==============================] - 69s 690ms/step - loss: -0.2800 - dice_coef: 0.2800 - val_loss: -0.0701 - val_dice_coef: 0.0701
# Epoch 130/200
# 100/100 [==============================] - 69s 687ms/step - loss: -0.2811 - dice_coef: 0.2811 - val_loss: -0.0699 - val_dice_coef: 0.0699
# Epoch 131/200
# 100/100 [==============================] - 69s 691ms/step - loss: -0.2847 - dice_coef: 0.2847 - val_loss: -0.0702 - val_dice_coef: 0.0702
# Epoch 132/200
# 100/100 [==============================] - 69s 689ms/step - loss: -0.2860 - dice_coef: 0.2860 - val_loss: -0.0704 - val_dice_coef: 0.0704
# Epoch 133/200
# 100/100 [==============================] - 69s 686ms/step - loss: -0.2904 - dice_coef: 0.2904 - val_loss: -0.0710 - val_dice_coef: 0.0710
# Epoch 134/200
# 100/100 [==============================] - 69s 687ms/step - loss: -0.2900 - dice_coef: 0.2900 - val_loss: -0.0708 - val_dice_coef: 0.0708
# Epoch 135/200
# 100/100 [==============================] - 69s 687ms/step - loss: -0.2942 - dice_coef: 0.2942 - val_loss: -0.0709 - val_dice_coef: 0.0709
# Epoch 136/200
# 100/100 [==============================] - 69s 688ms/step - loss: -0.2965 - dice_coef: 0.2965 - val_loss: -0.0712 - val_dice_coef: 0.0712
# Epoch 137/200
# 100/100 [==============================] - 69s 690ms/step - loss: -0.2975 - dice_coef: 0.2975 - val_loss: -0.0712 - val_dice_coef: 0.0712
# Epoch 138/200
# 100/100 [==============================] - 69s 688ms/step - loss: -0.3010 - dice_coef: 0.3010 - val_loss: -0.0714 - val_dice_coef: 0.0714
# Epoch 139/200
# 100/100 [==============================] - 69s 690ms/step - loss: -0.2992 - dice_coef: 0.2992 - val_loss: -0.0716 - val_dice_coef: 0.0716
# Epoch 140/200
# 100/100 [==============================] - 69s 686ms/step - loss: -0.3059 - dice_coef: 0.3059 - val_loss: -0.0720 - val_dice_coef: 0.0720
# Epoch 141/200
# 100/100 [==============================] - 69s 691ms/step - loss: -0.3074 - dice_coef: 0.3074 - val_loss: -0.0720 - val_dice_coef: 0.0720
# Epoch 142/200
# 100/100 [==============================] - 69s 689ms/step - loss: -0.3087 - dice_coef: 0.3087 - val_loss: -0.0724 - val_dice_coef: 0.0724
# Epoch 143/200
# 100/100 [==============================] - 69s 685ms/step - loss: -0.3124 - dice_coef: 0.3124 - val_loss: -0.0724 - val_dice_coef: 0.0724
# Epoch 144/200
# 100/100 [==============================] - 69s 685ms/step - loss: -0.3163 - dice_coef: 0.3163 - val_loss: -0.0723 - val_dice_coef: 0.0723
# Epoch 145/200
# 100/100 [==============================] - 69s 693ms/step - loss: -0.3162 - dice_coef: 0.3162 - val_loss: -0.0723 - val_dice_coef: 0.0723
# Epoch 146/200
# 100/100 [==============================] - 69s 688ms/step - loss: -0.3210 - dice_coef: 0.3210 - val_loss: -0.0725 - val_dice_coef: 0.0725
# Epoch 147/200
# 100/100 [==============================] - 69s 687ms/step - loss: -0.3215 - dice_coef: 0.3215 - val_loss: -0.0727 - val_dice_coef: 0.0727
# Epoch 148/200
# 100/100 [==============================] - 69s 693ms/step - loss: -0.3214 - dice_coef: 0.3214 - val_loss: -0.0731 - val_dice_coef: 0.0731
# Epoch 149/200
# 100/100 [==============================] - 69s 692ms/step - loss: -0.3261 - dice_coef: 0.3261 - val_loss: -0.0734 - val_dice_coef: 0.0734
# Epoch 150/200
# 100/100 [==============================] - 69s 689ms/step - loss: -0.3288 - dice_coef: 0.3288 - val_loss: -0.0735 - val_dice_coef: 0.0735
# Epoch 151/200
# 100/100 [==============================] - 69s 688ms/step - loss: -0.3295 - dice_coef: 0.3295 - val_loss: -0.0734 - val_dice_coef: 0.0734
# Epoch 152/200
# 100/100 [==============================] - 69s 688ms/step - loss: -0.3321 - dice_coef: 0.3321 - val_loss: -0.0738 - val_dice_coef: 0.0738
# Epoch 153/200
# 100/100 [==============================] - 69s 690ms/step - loss: -0.3371 - dice_coef: 0.3371 - val_loss: -0.0742 - val_dice_coef: 0.0742
# Epoch 154/200
# 100/100 [==============================] - 69s 689ms/step - loss: -0.3374 - dice_coef: 0.3374 - val_loss: -0.0741 - val_dice_coef: 0.0741
# Epoch 155/200
# 100/100 [==============================] - 69s 692ms/step - loss: -0.3405 - dice_coef: 0.3405 - val_loss: -0.0742 - val_dice_coef: 0.0742
# Epoch 156/200
# 100/100 [==============================] - 69s 689ms/step - loss: -0.3400 - dice_coef: 0.3400 - val_loss: -0.0745 - val_dice_coef: 0.0745
# Epoch 157/200
# 100/100 [==============================] - 69s 687ms/step - loss: -0.3461 - dice_coef: 0.3461 - val_loss: -0.0749 - val_dice_coef: 0.0749
# Epoch 158/200
# 100/100 [==============================] - 69s 689ms/step - loss: -0.3478 - dice_coef: 0.3478 - val_loss: -0.0751 - val_dice_coef: 0.0751
# Epoch 159/200
# 100/100 [==============================] - 69s 689ms/step - loss: -0.3541 - dice_coef: 0.3541 - val_loss: -0.0754 - val_dice_coef: 0.0754
# Epoch 160/200
# 100/100 [==============================] - 69s 691ms/step - loss: -0.3501 - dice_coef: 0.3501 - val_loss: -0.0756 - val_dice_coef: 0.0756
# Epoch 161/200
# 100/100 [==============================] - 69s 689ms/step - loss: -0.3552 - dice_coef: 0.3552 - val_loss: -0.0759 - val_dice_coef: 0.0759
# Epoch 162/200
# 100/100 [==============================] - 68s 684ms/step - loss: -0.3615 - dice_coef: 0.3615 - val_loss: -0.0763 - val_dice_coef: 0.0763
# Epoch 163/200
# 100/100 [==============================] - 69s 686ms/step - loss: -0.3603 - dice_coef: 0.3603 - val_loss: -0.0763 - val_dice_coef: 0.0763
# Epoch 164/200
# 100/100 [==============================] - 69s 686ms/step - loss: -0.3630 - dice_coef: 0.3630 - val_loss: -0.0767 - val_dice_coef: 0.0767
# Epoch 165/200
# 100/100 [==============================] - 68s 684ms/step - loss: -0.3656 - dice_coef: 0.3656 - val_loss: -0.0767 - val_dice_coef: 0.0767
# Epoch 166/200
# 100/100 [==============================] - 70s 695ms/step - loss: -0.3670 - dice_coef: 0.3670 - val_loss: -0.0777 - val_dice_coef: 0.0777
# Epoch 167/200
# 100/100 [==============================] - 69s 687ms/step - loss: -0.3736 - dice_coef: 0.3736 - val_loss: -0.0777 - val_dice_coef: 0.0777
# Epoch 168/200
# 100/100 [==============================] - 69s 687ms/step - loss: -0.3759 - dice_coef: 0.3759 - val_loss: -0.0777 - val_dice_coef: 0.0777
# Epoch 169/200
# 100/100 [==============================] - 69s 687ms/step - loss: -0.3764 - dice_coef: 0.3764 - val_loss: -0.0778 - val_dice_coef: 0.0778
# Epoch 170/200
# 100/100 [==============================] - 69s 689ms/step - loss: -0.3795 - dice_coef: 0.3795 - val_loss: -0.0786 - val_dice_coef: 0.0786
# Epoch 171/200
# 100/100 [==============================] - 69s 688ms/step - loss: -0.3831 - dice_coef: 0.3831 - val_loss: -0.0784 - val_dice_coef: 0.0784
# Epoch 172/200
# 100/100 [==============================] - 69s 686ms/step - loss: -0.3876 - dice_coef: 0.3876 - val_loss: -0.0783 - val_dice_coef: 0.0783
# Epoch 173/200
# 100/100 [==============================] - 68s 685ms/step - loss: -0.3903 - dice_coef: 0.3903 - val_loss: -0.0785 - val_dice_coef: 0.0785
# Epoch 174/200
# 100/100 [==============================] - 69s 688ms/step - loss: -0.3907 - dice_coef: 0.3907 - val_loss: -0.0786 - val_dice_coef: 0.0786
# Epoch 175/200
# 100/100 [==============================] - 69s 687ms/step - loss: -0.3917 - dice_coef: 0.3917 - val_loss: -0.0792 - val_dice_coef: 0.0792
# Epoch 176/200
# 100/100 [==============================] - 69s 687ms/step - loss: -0.3961 - dice_coef: 0.3961 - val_loss: -0.0799 - val_dice_coef: 0.0799
# Epoch 177/200
# 100/100 [==============================] - 69s 687ms/step - loss: -0.4006 - dice_coef: 0.4006 - val_loss: -0.0802 - val_dice_coef: 0.0802
# Epoch 178/200
# 100/100 [==============================] - 69s 688ms/step - loss: -0.4020 - dice_coef: 0.4020 - val_loss: -0.0799 - val_dice_coef: 0.0799
# Epoch 179/200
# 100/100 [==============================] - 69s 685ms/step - loss: -0.4075 - dice_coef: 0.4075 - val_loss: -0.0804 - val_dice_coef: 0.0804
# Epoch 180/200
# 100/100 [==============================] - 69s 685ms/step - loss: -0.4086 - dice_coef: 0.4086 - val_loss: -0.0805 - val_dice_coef: 0.0805
# Epoch 181/200
# 100/100 [==============================] - 69s 689ms/step - loss: -0.4117 - dice_coef: 0.4117 - val_loss: -0.0806 - val_dice_coef: 0.0806
# Epoch 182/200
# 100/100 [==============================] - 69s 688ms/step - loss: -0.4087 - dice_coef: 0.4087 - val_loss: -0.0806 - val_dice_coef: 0.0806
# Epoch 183/200
# 100/100 [==============================] - 68s 683ms/step - loss: -0.4177 - dice_coef: 0.4177 - val_loss: -0.0811 - val_dice_coef: 0.0811
# Epoch 184/200
# 100/100 [==============================] - 69s 686ms/step - loss: -0.4199 - dice_coef: 0.4199 - val_loss: -0.0815 - val_dice_coef: 0.0815
# Epoch 185/200
# 100/100 [==============================] - 68s 684ms/step - loss: -0.4220 - dice_coef: 0.4220 - val_loss: -0.0817 - val_dice_coef: 0.0817
# Epoch 186/200
# 100/100 [==============================] - 68s 683ms/step - loss: -0.4233 - dice_coef: 0.4233 - val_loss: -0.0825 - val_dice_coef: 0.0825
# Epoch 187/200
# 100/100 [==============================] - 69s 689ms/step - loss: -0.4289 - dice_coef: 0.4289 - val_loss: -0.0829 - val_dice_coef: 0.0829
# Epoch 188/200
# 100/100 [==============================] - 69s 687ms/step - loss: -0.4365 - dice_coef: 0.4365 - val_loss: -0.0829 - val_dice_coef: 0.0829
# Epoch 189/200
# 100/100 [==============================] - 69s 686ms/step - loss: -0.4329 - dice_coef: 0.4329 - val_loss: -0.0825 - val_dice_coef: 0.0825
# Epoch 190/200
# 100/100 [==============================] - 69s 687ms/step - loss: -0.4400 - dice_coef: 0.4400 - val_loss: -0.0828 - val_dice_coef: 0.0828
# Epoch 191/200
# 100/100 [==============================] - 69s 690ms/step - loss: -0.4368 - dice_coef: 0.4368 - val_loss: -0.0835 - val_dice_coef: 0.0835
# Epoch 192/200
# 100/100 [==============================] - 69s 687ms/step - loss: -0.4489 - dice_coef: 0.4489 - val_loss: -0.0847 - val_dice_coef: 0.0847
# Epoch 193/200
# 100/100 [==============================] - 69s 686ms/step - loss: -0.4438 - dice_coef: 0.4438 - val_loss: -0.0846 - val_dice_coef: 0.0846
# Epoch 194/200
# 100/100 [==============================] - 69s 688ms/step - loss: -0.4501 - dice_coef: 0.4501 - val_loss: -0.0850 - val_dice_coef: 0.0850
# Epoch 195/200
# 100/100 [==============================] - 69s 686ms/step - loss: -0.4516 - dice_coef: 0.4516 - val_loss: -0.0850 - val_dice_coef: 0.0850
# Epoch 196/200
# 100/100 [==============================] - 70s 700ms/step - loss: -0.4573 - dice_coef: 0.4573 - val_loss: -0.0847 - val_dice_coef: 0.0847
# Epoch 197/200
# 100/100 [==============================] - 69s 687ms/step - loss: -0.4607 - dice_coef: 0.4607 - val_loss: -0.0855 - val_dice_coef: 0.0855
# Epoch 198/200
# 100/100 [==============================] - 69s 685ms/step - loss: -0.4640 - dice_coef: 0.4640 - val_loss: -0.0861 - val_dice_coef: 0.0861
# Epoch 199/200
# 100/100 [==============================] - 68s 685ms/step - loss: -0.4683 - dice_coef: 0.4683 - val_loss: -0.0864 - val_dice_coef: 0.0864
# Epoch 200/200
# 100/100 [==============================] - 69s 686ms/step - loss: -0.4663 - dice_coef: 0.4663 - val_loss: -0.0862 - val_dice_coef: 0.0862
# ------------------------------
# Done !!
# ------------------------------

# %%
plt.plot(history.history['loss'], 'y', label='loss')
plt.plot(history.history['val_loss'], 'r', label='val_loss')
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend(loc='upper right')
plt.show()

# %%
plt.plot(history.history['dice_coef'], 'b', label='dice_coef')
plt.plot(history.history['val_dice_coef'], 'g', label='val_dice_coef')
plt.xlabel('epoch')
plt.ylabel('dice_coef')
plt.legend(loc='lower right')
plt.show()

# %%
import pandas as pd

df = pd.DataFrame({"loss": history.history['loss'],  "val_loss": history.history['val_loss'],
                   "dice_coef": history.history['dice_coef'],  "val_dice_coef": history.history['val_dice_coef'], })
df.to_csv('/content/gdrive/My Drive/Colab Notebooks/history_{:2.2}.csv'.format(history.history['val_dice_coef'][-1]))
model.save_weights("/content/gdrive/My Drive/Colab Notebooks/model_{:2.2}.h5".format(history.history['val_dice_coef'][-1]))

# %%
import cv2

mask_predict = model.predict(image_valid, verbose=1)
score = model.evaluate(mask_predict, mask_valid , verbose=1)

print('Test score:', score[0])
print('Test accuracy:', score[1])
# Out:
# 465/465 [==============================] - 4s 8ms/step
# 465/465 [==============================] - 1s 3ms/step
# Test score: -0.08801502869013816
# Test accuracy: 0.08801502869013816

# %%
mask_r = mask_predict.reshape(465, 96, 96)
mask_test_u = mask_valid.reshape(465, 96, 96)
image_test_u = image_valid.reshape(465, 96, 96)

img_test_o = (mask_r*2)+image_test_u
img_predict_o =image_test_u+(mask_test_u*2)

# %%
plt.figure()
plt.imshow(mask_test_u[35], cmap='gray')
plt.show()

plt.figure()
plt.imshow( mask_r[35], cmap='gray')
plt.show()

plt.figure()
plt.imshow(img_test_o[35], cmap='gray')
plt.show()

plt.figure()
plt.imshow(img_predict_o[35], cmap='gray')
plt.show()
